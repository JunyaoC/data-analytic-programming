# %% [markdown]
# ### Simple Challenge 4
#
# In pandas library, you can read CSV data file using the ```read_csv``` function in pandas. The function will read the csv data file straight into data frame, with the default setting where 1st row of the data file will become the header of the data frame.
#
#
# view on github: https://go.midknight.co/e9r

# %%
import pandas as pd

data = pd.read_csv('telco-customer-churn.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# TASK 1

seniorCitizen = data['SeniorCitizen'] == 1
tenureData = data['tenure'] > 12

seniorJoinTenure = pd.merge( data[seniorCitizen],data[tenureData],how='inner')

display(seniorJoinTenure)
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    3841-NFECX  Female              1     Yes         No      71
# 1    8012-SOUDQ  Female              1      No         No      43
# 2    6575-SUVOI  Female              1     Yes         No      25
# 3    4667-QONEA  Female              1     Yes        Yes      60
# 4    1658-BYGOY    Male              1      No         No      18
# ..          ...     ...            ...     ...        ...     ...
# 817  6583-QGCSI  Female              1     Yes         No      50
# 818  2274-XUATA    Male              1     Yes         No      72
# 819  0666-UXTJO    Male              1     Yes         No      34
# 820  1035-IPQPU  Female              1     Yes         No      63
# 821  3605-JISKB    Male              1     Yes         No      55
#
#     PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0            Yes               Yes     Fiber optic            Yes  ...
# ...

# %%
# TASK 2

churn = data['Churn'].value_counts()
churnCount = churn['Yes']
print(churnCount)

churnDF = data[ data['Churn'] == 'Yes']

tenureMIN = churnDF['tenure'].min()
print(tenureMIN)

tenureMAX = churnDF['tenure'].max()
print(tenureMAX)

tenureAVG = churnDF['tenure'].mean()
print(tenureAVG)
# Out:
# 1869
# 1
# 72
# 17.979133226324237

# %%
# TASK 3

tenureDF = data[data['tenure'] > 12]

resultDF = tenureDF.loc[ :, ['customerID','Churn','InternetService','StreamingTV','tenure','Contract','MonthlyCharges'] ]

resultDF = resultDF.sort_values(['tenure','MonthlyCharges'] , ascending=[True,False])
display(resultDF)
# Out:
#       customerID Churn InternetService          StreamingTV  tenure  \
# 261   3606-TWKGI   Yes     Fiber optic                  Yes      13
# 6193  5716-LIBJC    No     Fiber optic                  Yes      13
# 6125  0871-URUWO   Yes     Fiber optic                  Yes      13
# 2708  8510-AWCXC   Yes     Fiber optic                  Yes      13
# 6714  7315-WYOAW    No     Fiber optic                  Yes      13
# ...          ...   ...             ...                  ...     ...
# 4201  1166-PQLGG    No              No  No internet service      72
# 109   2848-YXSMW    No              No  No internet service      72
# 1329  3910-MRQOY    No              No  No internet service      72
# 932   5787-KXGIY    No              No  No internet service      72
# 2693  3976-HXHCE    No              No  No internet service      72
#
#             Contract  MonthlyCharges
# 261   Month-to-month          106.90
# 6193        One year          104.15
# ...

# %% [markdown]
# <a href="https://www.buymeacoffee.com/junyaoc" target="_blank"><img src="https://img.buymeacoffee.com/button-api/?text=Buy me a coffee&emoji=&slug=junyaoc&button_colour=FFDD00&font_colour=000000&font_family=Lato&outline_colour=000000&coffee_colour=ffffff"></a>
#
# :D
